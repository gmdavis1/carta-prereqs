# %%
import numpy as np
import pandas as pd
import pickle
import tqdm.auto as tqdm
import re
import sklearn
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from hdbscan import HDBSCAN
from pprint import pprint
from explorecourses import *

# %%
def load_csvs(pathname):
    RESULTS_FULL_PATH_CSV = "../results/" + pathname + "_full.csv"
    RESULTS_PREREQ_PATH_CSV = "../results/" + pathname + "_prereq.csv"
    COEFS_FULL_PATH_CSV = "../results/" + pathname + "_coefs_full.csv"
    COEFS_PREREQ_PATH_CSV = "../results/" + pathname + "_coefs_prereq.csv"
    
    results_full_df = pd.read_csv(RESULTS_FULL_PATH_CSV, low_memory=False).rename(
        columns={"Unnamed: 0":"course"}).set_index("course")
    results_prereq_df = pd.read_csv(RESULTS_PREREQ_PATH_CSV, low_memory=False).rename(
        columns={"Unnamed: 0":"course"}).set_index("course")
    coefs_full_df = pd.read_csv(COEFS_FULL_PATH_CSV, low_memory=False).rename(
        columns={"Unnamed: 0":"course"}).set_index("course")
    coefs_prereq_df = pd.read_csv(COEFS_PREREQ_PATH_CSV, low_memory=False).rename(
        columns={"Unnamed: 0":"course"}).set_index("course")
    
    return results_full_df, results_prereq_df, coefs_full_df, coefs_prereq_df

# modifies the df in place
def remove_advcourse_coefs(df):
    RE_PATTERN = r"(.+?)(\d+)"

    for ind in df.index:
        ind_split = re.split(RE_PATTERN, ind)
        ind_dept = ind_split[1]
        ind_num = int(ind_split[2])
        for col in df.columns:
            col_split = re.split(RE_PATTERN, col)
            col_dept = col_split[1]
            col_num = int(col_split[2])

            # same department, course code's hundreds digit is higher
            if ind_dept == col_dept and col_num // 100 > ind_num // 100:
                df.loc[ind, col] = None
                
def rowwise_normalize(df):
    return df.div(df.sum(axis=1), axis=0)

# %% [markdown]
# ### LASSO positive-only, variable lambda

# %%
pathname = "lasso_positive_variable_lambda"

lasso_positive_results_full, lasso_positive_results_prereq, lasso_positive_coefs_full, lasso_positive_coefs_prereq \
= load_csvs(pathname)

# remove coefs for courses in the same dept that are higher level (e.g. CS221 shouldn't be a predictor for CS106A)
remove_advcourse_coefs(lasso_positive_coefs_full)

# normalize by making all rows sum to 1
norm_lasso_positive_coefs_full = rowwise_normalize(lasso_positive_coefs_full)
display(norm_lasso_positive_coefs_full)
# Out:
#             CME100  CHEM31X  CME102  CHEM33  ENGR20  CME104  CHEM35  \
# course
# CHEMENG162     NaN      NaN     NaN     NaN     NaN     NaN     NaN
# MS&E245G       0.0      0.0     0.0     0.0     NaN     0.0     NaN
# PUBLPOL105     NaN      NaN     NaN     NaN     NaN     NaN     NaN
# PHYSICS61      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# MS&E145        NaN      NaN     NaN     NaN     NaN     NaN     NaN
# ...            ...      ...     ...     ...     ...     ...     ...
# MATH147        NaN      NaN     NaN     NaN     NaN     NaN     NaN
# MATH175        NaN      NaN     NaN     NaN     NaN     NaN     NaN
# MATH146        NaN      0.0     0.0     NaN     NaN     NaN     NaN
# MATH145        NaN      NaN     NaN     NaN     NaN     NaN     NaN
# MATH51H        NaN      NaN     NaN     NaN     NaN     NaN     NaN
#
#             CHEMENG100  CHEM131  CHEMENG120A  ...  COMM277A  PHYSICS364  \
# course                                        ...
# CHEMENG162         NaN      NaN          NaN  ...       NaN         NaN
# MS&E245G           NaN      NaN          NaN  ...       NaN         NaN
# PUBLPOL105         NaN      NaN          NaN  ...       NaN         NaN
# PHYSICS61          NaN      NaN          NaN  ...       NaN         NaN
# MS&E145            NaN      NaN          NaN  ...       NaN         NaN
# ...                ...      ...          ...  ...       ...         ...
# MATH147            NaN      NaN          NaN  ...       NaN         NaN
# MATH175            NaN      NaN          NaN  ...       NaN         NaN
# MATH146            NaN      NaN          NaN  ...       NaN         NaN
# MATH145            NaN      NaN          NaN  ...       NaN         NaN
# MATH51H            NaN      NaN          NaN  ...       NaN         NaN
#
#             CHEMENG345  PSYCH178  MATH138  GEOPHYS146A  CEE274D  PHIL350A  \
# course
# CHEMENG162         NaN       NaN      NaN          NaN      NaN       NaN
# MS&E245G           NaN       NaN      NaN          NaN      NaN       NaN
# PUBLPOL105         NaN       NaN      NaN          NaN      NaN       NaN
# PHYSICS61          NaN       NaN      NaN          NaN      NaN       NaN
# MS&E145            NaN       NaN      NaN          NaN      NaN       NaN
# ...                ...       ...      ...          ...      ...       ...
# MATH147            NaN       NaN      NaN          NaN      NaN       NaN
# MATH175            NaN       NaN      NaN          NaN      NaN       NaN
# MATH146            NaN       NaN      NaN          NaN      NaN       NaN
# MATH145            NaN       NaN      NaN          NaN      NaN       NaN
# MATH51H            NaN       NaN      NaN          NaN      NaN       NaN
#
#             MATH248  GEOPHYS281
# course
# CHEMENG162      NaN         NaN
# MS&E245G        NaN         NaN
# PUBLPOL105      NaN         NaN
# PHYSICS61       NaN         NaN
# MS&E145         NaN         NaN
# ...             ...         ...
# MATH147         NaN         NaN
# MATH175         NaN         NaN
# MATH146         NaN         NaN
# MATH145         NaN         NaN
# MATH51H         NaN         NaN
#
# [316 rows x 871 columns]

# %%
idx = norm_lasso_positive_coefs_full.index[norm_lasso_positive_coefs_full.isnull().all(1)]
nans = norm_lasso_positive_coefs_full.loc[idx]
nans = nans.sort_values(by = 'course') 
nans
# Out:
#           CME100  CHEM31X  CME102  CHEM33  ENGR20  CME104  CHEM35  CHEMENG100  \
# course
# AA100        NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# AA279A       NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# BIO101       NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# BIO115       NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# BIO144       NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# ...          ...      ...     ...     ...     ...     ...     ...         ...
# STATS141     NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# STATS191     NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# STATS203     NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# STATS217     NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
# STATS60      NaN      NaN     NaN     NaN     NaN     NaN     NaN         NaN
#
#           CHEM131  CHEMENG120A  ...  COMM277A  PHYSICS364  CHEMENG345  \
# course                          ...
# AA100         NaN          NaN  ...       NaN         NaN         NaN
# AA279A        NaN          NaN  ...       NaN         NaN         NaN
# BIO101        NaN          NaN  ...       NaN         NaN         NaN
# BIO115        NaN          NaN  ...       NaN         NaN         NaN
# BIO144        NaN          NaN  ...       NaN         NaN         NaN
# ...           ...          ...  ...       ...         ...         ...
# STATS141      NaN          NaN  ...       NaN         NaN         NaN
# STATS191      NaN          NaN  ...       NaN         NaN         NaN
# STATS203      NaN          NaN  ...       NaN         NaN         NaN
# STATS217      NaN          NaN  ...       NaN         NaN         NaN
# STATS60       NaN          NaN  ...       NaN         NaN         NaN
#
#           PSYCH178  MATH138  GEOPHYS146A  CEE274D  PHIL350A  MATH248  \
# course
# AA100          NaN      NaN          NaN      NaN       NaN      NaN
# AA279A         NaN      NaN          NaN      NaN       NaN      NaN
# BIO101         NaN      NaN          NaN      NaN       NaN      NaN
# BIO115         NaN      NaN          NaN      NaN       NaN      NaN
# BIO144         NaN      NaN          NaN      NaN       NaN      NaN
# ...            ...      ...          ...      ...       ...      ...
# STATS141       NaN      NaN          NaN      NaN       NaN      NaN
# STATS191       NaN      NaN          NaN      NaN       NaN      NaN
# STATS203       NaN      NaN          NaN      NaN       NaN      NaN
# STATS217       NaN      NaN          NaN      NaN       NaN      NaN
# STATS60        NaN      NaN          NaN      NaN       NaN      NaN
#
#           GEOPHYS281
# course
# AA100            NaN
# AA279A           NaN
# BIO101           NaN
# BIO115           NaN
# BIO144           NaN
# ...              ...
# STATS141         NaN
# STATS191         NaN
# STATS203         NaN
# STATS217         NaN
# STATS60          NaN
#
# [161 rows x 871 columns]

# %%
# get all the nan courses
nan_courses = []
for index, value in nans['MATH51'].items():
    nan_courses.append(index)
nan_courses
# Out:
# ['AA100',
#  'AA279A',
#  'BIO101',
#  'BIO115',
#  'BIO144',
#  'BIOE123',
#  'BIOE44',
#  'CEE166B',
#  'CEE176B',
#  'CEE180',
#  'CEE181',
#  'CEE70',
#  'CHEM134',
#  'CHEM135',
#  'CHEM176',
#  'CHEM31A',
#  'CHEMENG120B',
#  'CHEMENG162',
#  'CHEMENG174',
#  'CHEMENG185A',
#  'CHEMENG20',
#  'CHEMENG25B',
#  'CME100',
#  'CME100A',
#  'CME102A',
#  'CME104A',
#  'CME108',
#  'COMM106',
#  'COMM108',
#  'CS106A',
#  'CS106B',
#  'CS106X',
#  'CS107E',
#  'CS131',
#  'CS147',
#  'CS148',
#  'CS181',
#  'CS193A',
#  'CS194H',
#  'CS210B',
#  'CS224N',
#  'CS224S',
#  'CS224U',
#  'CS227B',
#  'CS240',
#  'CS242',
#  'CS245',
#  'CS247',
#  'CS248',
#  'CS261',
#  'CS265',
#  'CS279',
#  'CS348B',
#  'CS377U',
#  'EARTHSYS111',
#  'EARTHSYS112',
#  'ECON1',
#  'ECON111',
#  'ECON112',
#  'ECON126',
#  'ECON136',
#  'ECON140',
#  'ECON141',
#  'ECON143',
#  'ECON145',
#  'ECON159',
#  'ECON178',
#  'EE103',
#  'EE107',
#  'EE134',
#  'EE142',
#  'EE155',
#  'EE178',
#  'EE222',
#  'EE271',
#  'EE364A',
#  'ENERGY102',
#  'ENERGY104',
#  'ENERGY160',
#  'ENGR10',
#  'ENGR20',
#  'ENGR205',
#  'ENGR30',
#  'ENGR50',
#  'ENGR62',
#  'HUMBIO128',
#  'HUMBIO129S',
#  'IPS207',
#  'LINGUIST1',
#  'LINGUIST105',
#  'LINGUIST130A',
#  'LINGUIST130B',
#  'MATH107',
#  'MATH109',
#  'MATH115',
#  'MATH116',
#  'MATH120',
#  'MATH121',
#  'MATH122',
#  'MATH143',
#  'MATH145',
#  'MATH147',
#  'MATH171',
#  'MATH175',
#  'MATH19',
#  'MATH205B',
#  'MATH41',
#  'MATH51',
#  'MATH51H',
#  'MCS100',
#  'ME101',
#  'ME112',
#  'ME113',
#  'ME115A',
#  'ME115B',
#  'ME140',
#  'ME210',
#  'ME216A',
#  'ME216B',
#  'ME318',
#  'ME346A',
#  'MS&E125',
#  'MS&E145',
#  'MS&E211',
#  'MS&E245A',
#  'MS&E260',
#  'OSPBER40M',
#  'OSPKYOTO40M',
#  'PHIL1',
#  'PHIL102',
#  'PHIL150',
#  'PHIL152',
#  'PHIL180',
#  'PHIL181',
#  'PHIL184',
#  'PHIL186',
#  'PHIL80',
#  'PHYSICS108',
#  'PHYSICS110',
#  'PHYSICS113',
#  'PHYSICS120',
#  'PHYSICS171',
#  'PHYSICS262',
#  'PHYSICS330',
#  'PHYSICS41A',
#  'PHYSICS61',
#  'PSYCH1',
#  'PSYCH141',
#  'PSYCH146',
#  'PSYCH147',
#  'PSYCH50',
#  'PSYCH60',
#  'PSYCH60B',
#  'PSYCH90',
#  'PSYCH95',
#  'PUBLPOL105',
#  'STATS141',
#  'STATS191',
#  'STATS203',
#  'STATS217',
#  'STATS60']

# %%
non_nans = norm_lasso_positive_coefs_full.drop(nans.index, axis=0)
assert(non_nans.sum(axis=1).all() == 1.0)
non_nans
# Out:
#               CME100   CHEM31X    CME102    CHEM33  ENGR20  CME104    CHEM35  \
# course
# MS&E245G    0.000000  0.000000  0.000000  0.000000     NaN     0.0       NaN
# CME106      0.336257  0.000000  0.026704  0.179617     0.0     0.0  0.000000
# BIO42       0.000000  0.000000  0.000000  0.000000     0.0     0.0  0.000000
# PSYCH30     0.030488  0.000000  0.000000  0.044007     0.0     0.0  0.000000
# PUBLPOL104  0.000000  0.000000  0.000000  0.000000     NaN     NaN  0.000000
# ...              ...       ...       ...       ...     ...     ...       ...
# PHYSICS21   0.075049  0.124545  0.000000  0.061820     NaN     0.0  0.087371
# CHEMENG150  0.000000  0.000000  0.000000  0.000000     0.0     0.0  0.000000
# STATS202    0.066800  0.000000  0.000000  0.053808     0.0     0.0  0.000000
# ECON102B    0.000000  0.003462  0.000000  0.000000     0.0     0.0  0.000000
# MATH146          NaN  0.000000  0.000000       NaN     NaN     NaN       NaN
#
#             CHEMENG100  CHEM131  CHEMENG120A  ...  COMM277A  PHYSICS364  \
# course                                        ...
# MS&E245G           NaN      NaN          NaN  ...       NaN         NaN
# CME106        0.000000      0.0          0.0  ...       NaN         NaN
# BIO42         0.000000      0.0          0.0  ...       NaN         NaN
# PSYCH30       0.000000      0.0          0.0  ...       NaN         NaN
# PUBLPOL104         NaN      0.0          NaN  ...       NaN         NaN
# ...                ...      ...          ...  ...       ...         ...
# PHYSICS21          NaN      0.0          NaN  ...       NaN         NaN
# CHEMENG150    0.465792      0.0          0.0  ...       NaN         NaN
# STATS202      0.000000      0.0          0.0  ...       0.0         NaN
# ECON102B      0.000000      0.0          0.0  ...       NaN         NaN
# MATH146            NaN      NaN          NaN  ...       NaN         NaN
#
#             CHEMENG345  PSYCH178  MATH138  GEOPHYS146A  CEE274D  PHIL350A  \
# course
# MS&E245G           NaN       NaN      NaN          NaN      NaN       NaN
# CME106             NaN       NaN      NaN          NaN      NaN       NaN
# BIO42              NaN       NaN      NaN          NaN      NaN       NaN
# PSYCH30            NaN       NaN      NaN          NaN      NaN       NaN
# PUBLPOL104         NaN       NaN      NaN          NaN      NaN       NaN
# ...                ...       ...      ...          ...      ...       ...
# PHYSICS21          NaN       NaN      NaN          NaN      NaN       NaN
# CHEMENG150         NaN       NaN      NaN          NaN      NaN       NaN
# STATS202           NaN       NaN      NaN          NaN      NaN       NaN
# ECON102B           NaN       NaN      NaN          NaN      NaN       NaN
# MATH146            NaN       NaN      NaN          NaN      NaN       NaN
#
#             MATH248  GEOPHYS281
# course
# MS&E245G        NaN         NaN
# CME106          NaN         NaN
# BIO42           NaN         NaN
# PSYCH30         NaN         NaN
# PUBLPOL104      NaN         NaN
# ...             ...         ...
# PHYSICS21       NaN         NaN
# CHEMENG150      NaN         NaN
# STATS202        NaN         NaN
# ECON102B        NaN         NaN
# MATH146         NaN         NaN
#
# [155 rows x 871 columns]

# %%
# list of all preparatory courses
prep_courses = non_nans.columns[(non_nans.sum(axis=0) != 0)]
prep_courses
# Out:
# Index(['CME100', 'CHEM31X', 'CME102', 'CHEM33', 'ENGR20', 'CME104', 'CHEM35',
#        'CHEMENG100', 'CHEM131', 'CS106A',
#        ...
#        'COMM113', 'GS4', 'PHIL50', 'STATS141', 'CS272', 'GS90', 'ECON154',
#        'MATH180', 'ECON125', 'EE42'],
#       dtype='object', length=215)

# %%
# list of all target courses
target_courses = non_nans.index
target_courses
# Out:
# Index(['MS&E245G', 'CME106', 'BIO42', 'PSYCH30', 'PUBLPOL104', 'MS&E252',
#        'MATH42', 'BIOE41', 'AA242A', 'BIOE101',
#        ...
#        'PHYSICS121', 'ME227', 'CS223A', 'ME80', 'EE65', 'PHYSICS21',
#        'CHEMENG150', 'STATS202', 'ECON102B', 'MATH146'],
#       dtype='object', name='course', length=155)

# %%
top_preps = non_nans.sum().sort_values(ascending=False)[:20].index
set(top_preps).difference(set(target_courses)) # top prep courses that don't have a target course model
# Out:
# {'CHEM171',
#  'CME100',
#  'CS106A',
#  'CS106B',
#  'CS106X',
#  'ECON1',
#  'ECON50',
#  'MATH51',
#  'PSYCH1'}

# %% [markdown]
# #### columnwise sums to find total weight of all preparatory courses

# %%
def get_course_name(row):
    BASIC_PATTERN = r"([A-Z]+)\s*([\d]+[A-Z]*)"
    course_code = row["Course code"]
    dept = re.search(BASIC_PATTERN, course_code).group(1)
    num = re.search(BASIC_PATTERN, course_code).group(2)
    connect = CourseConnection()
    for course in connect.get_courses_by_query(course_code):
        if course.subject == dept and course.code == num:
            return course.title

# %%
table = non_nans.sum().sort_values(ascending=False)[:len(prep_courses)].to_frame().reset_index()
table.rename(columns={"index":"Course code", 0:"Weight"}, inplace=True)
table["Prop. of total weight"] = table["Weight"] / table["Weight"].sum()
table["Course title"] = table.apply(get_course_name, axis=1)

# %%
table = table[["Course code", "Course title", "Prop. of total weight"]]
print(table[:20].to_latex(index=False))
# Out:
# \begin{tabular}{llr}
# \toprule
# Course code &                                       Course title &  Prop. of total weight \\
# \midrule
#      MATH51 &  Linear Algebra, Multivariable Calculus, and Mo... &               0.075462 \\
#       CS107 &                  Computer Organization and Systems &               0.072055 \\
#      CS106B &                           Programming Abstractions &               0.041371 \\
#       CS103 &              Mathematical Foundations of Computing &               0.033710 \\
#      CHEM33 &      Structure and Reactivity of Organic Molecules &               0.031736 \\
#      CME102 &  Ordinary Differential Equations for Engineers ... &               0.029191 \\
#      CME100 &           Vector Calculus for Engineers (ENGR 154) &               0.027938 \\
#      ECON50 &                                Economic Analysis I &               0.027140 \\
#      CHEM35 &                                               None &               0.027070 \\
#       CS110 &                     Principles of Computer Systems &               0.025707 \\
#       ECON1 &                            Principles of Economics &               0.022909 \\
#      CS106X &             Programming Abstractions (Accelerated) &               0.020601 \\
#      PSYCH1 &                         Introduction to Psychology &               0.020377 \\
#      MATH53 &  Ordinary Differential Equations with Linear Al... &               0.020351 \\
#      CS106A &                            Programming Methodology &               0.019426 \\
#     CHEM171 &                  Foundations of Physical Chemistry &               0.017975 \\
#       CS161 &                  Design and Analysis of Algorithms &               0.017489 \\
#      EE102A &             Signal Processing and Linear Systems I &               0.017419 \\
#    HUMBIO2A &                   Genetics, Evolution, and Ecology &               0.017006 \\
#   PHYSICS45 &                                     Light and Heat &               0.015530 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### trying clustering but results aren't that good

# %%
clustering = DBSCAN(eps=0.4, min_samples=2).fit(norm_highach_coefs_full.fillna(0).T)
clusters = {}
for i, label in enumerate(clustering.labels_):
    if (label in clusters):
        clusters[label].append(norm_highach_coefs_full.columns[i])
    else:
        clusters[label] = [norm_highach_coefs_full.columns[i]]
pprint(clusters)

# %%
clustering = OPTICS(min_samples=2).fit(norm_highach_coefs_full.fillna(0).T)
clusters = {}
for i, label in enumerate(clustering.labels_):
    if (label in clusters):
        clusters[label].append(norm_highach_coefs_full.columns[i])
    else:
        clusters[label] = [norm_highach_coefs_full.columns[i]]
pprint(clusters)

# %%
clustering = HDBSCAN(min_cluster_size=2, min_samples=100).fit(norm_highach_coefs_full.fillna(0).T)
clusters = {}
for i, label in enumerate(clustering.labels_):
    if (label in clusters):
        clusters[label].append(norm_highach_coefs_full.columns[i])
    else:
        clusters[label] = [norm_highach_coefs_full.columns[i]]
pprint(clusters)
